# %%
import pandas as pd

# %%
Boston = pd.read_csv("Boston.csv")

# %%
Boston.head(150)
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...    ...     ...  ...
# 145         146  2.37934   0.0  19.58     0  0.871  6.130  100.0  1.4191    5
# 146         147  2.15505   0.0  19.58     0  0.871  5.628  100.0  1.5166    5
# 147         148  2.36862   0.0  19.58     0  0.871  4.926   95.7  1.4608    5
# 148         149  2.33099   0.0  19.58     0  0.871  5.186   93.8  1.5296    5
# 149         150  2.73397   0.0  19.58     0  0.871  5.597   94.9  1.5257    5
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 145  403     14.7  172.91  27.80  13.8
# 146  403     14.7  169.27  16.65  15.6
# 147  403     14.7  391.71  29.53  14.6
# 148  403     14.7  356.99  28.32  17.8
# 149  403     14.7  351.85  21.45  15.4
#
# [150 rows x 15 columns]

# %%
y = Boston['medv']

# %%
x = Boston[["crim"]]

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.3)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()
