# %% [markdown]
# # Exploratory Data Analysis of Big Data Set

# %%
# Importing important Libraries

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Importing dataset from google drive

from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
url = "/gdrive/MyDrive/Ahmedapps/en.openfoodfacts.org.products.tsv"
food = pd.read_csv(url,sep='\t')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Step 1 of EDA analysis

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %%
food.shape
# Out:
# (356027, 163)

# %%
rows, cols = food.shape
print("numbers of rows is :", rows) # instances
print("numbers of cols is :", cols) # series
# Out:
# numbers of rows is : 356027
# numbers of cols is : 163

# %%
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# # Step 2 of EDA Analysis

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 442.8+ MB

# %% [markdown]
# ### Step 3 of EDA analysis

# %% [markdown]
# find missing values

# %%
food.isnull()
# Out:
#          code    url  creator  created_t  created_datetime  last_modified_t  \
# 0       False  False    False      False             False            False
# 1       False  False    False      False             False            False
# 2       False  False    False      False             False            False
# 3       False  False    False      False             False            False
# 4       False  False    False      False             False            False
# ...       ...    ...      ...        ...               ...              ...
# 356022  False  False    False      False             False            False
# 356023  False  False    False      False             False            False
# 356024  False  False    False      False             False            False
# 356025  False  False    False      False             False            False
# 356026  False  False    False      False             False            False
#
#         last_modified_datetime  product_name  generic_name  quantity  ...  \
# 0                        False         False          True     False  ...
# 1                        False         False          True      True  ...
# 2                        False         False          True      True  ...
# 3                        False         False          True      True  ...
# 4                        False         False          True      True  ...
# ...                        ...           ...           ...       ...  ...
# 356022                   False         False          True      True  ...
# 356023                   False         False         False     False  ...
# 356024                   False         False          True     False  ...
# 356025                   False         False          True     False  ...
# 356026                   False         False          True      True  ...
#
#         fruits-vegetables-nuts_100g  fruits-vegetables-nuts-estimate_100g  \
# 0                              True                                  True
# 1                              True                                  True
# 2                              True                                  True
# 3                              True                                  True
# 4                              True                                  True
# ...                             ...                                   ...
# 356022                         True                                  True
# 356023                         True                                  True
# 356024                         True                                  True
# 356025                         True                                  True
# 356026                         True                                  True
#
#         collagen-meat-protein-ratio_100g  cocoa_100g  chlorophyl_100g  \
# 0                                   True        True             True
# 1                                   True        True             True
# 2                                   True        True             True
# 3                                   True        True             True
# 4                                   True        True             True
# ...                                  ...         ...              ...
# 356022                              True        True             True
# 356023                              True        True             True
# 356024                              True        True             True
# 356025                              True        True             True
# 356026                              True        True             True
#
#         carbon-footprint_100g  nutrition-score-fr_100g  \
# 0                        True                     True
# 1                        True                    False
# 2                        True                    False
# 3                        True                    False
# 4                        True                     True
# ...                       ...                      ...
# 356022                   True                    False
# 356023                   True                     True
# 356024                   True                     True
# 356025                   True                     True
# 356026                   True                     True
#
#         nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# 0                          True                 True                 True
# 1                         False                 True                 True
# 2                         False                 True                 True
# 3                         False                 True                 True
# 4                          True                 True                 True
# ...                         ...                  ...                  ...
# 356022                    False                 True                 True
# 356023                     True                 True                 True
# 356024                     True                 True                 True
# 356025                     True                 True                 True
# 356026                     True                 True                 True
#
# [356027 rows x 163 columns]

# %%
food.isnull().sum()
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %%
# percent calculation of missing values
food.isnull().sum() /food.shape[0]*100
# Out:
# code                         0.007303
# url                          0.007303
# creator                      0.000843
# created_t                    0.000843
# created_datetime             0.002809
#                               ...
# carbon-footprint_100g       99.921916
# nutrition-score-fr_100g     28.416665
# nutrition-score-uk_100g     28.416665
# glycemic-index_100g        100.000000
# water-hardness_100g        100.000000
# Length: 163, dtype: float64

# %% [markdown]
# # Step 4 of EDA Analysis

# %% [markdown]
# split variables for new columns needed

# %%
food[['url type','second_part']] = food['url'].str.split(':', expand = True)

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... collagen-meat-protein-ratio_100g cocoa_100g  \
# 0          NaN      1kg  ...                              NaN        NaN
# 1          NaN      NaN  ...                              NaN        NaN
# 2          NaN      NaN  ...                              NaN        NaN
# 3          NaN      NaN  ...                              NaN        NaN
# 4          NaN      NaN  ...                              NaN        NaN
#
#   chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0             NaN                   NaN                     NaN
# 1             NaN                   NaN                    14.0
# 2             NaN                   NaN                     0.0
# 3             NaN                   NaN                    12.0
# 4             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g url type  \
# 0                     NaN                 NaN                 NaN     http
# 1                    14.0                 NaN                 NaN     http
# 2                     0.0                 NaN                 NaN     http
# 3                    12.0                 NaN                 NaN     http
# 4                     NaN                 NaN                 NaN     http
#
#                                          second_part
# 0  //world-en.openfoodfacts.org/product/000000000...
# 1  //world-en.openfoodfacts.org/product/000000000...
# 2  //world-en.openfoodfacts.org/product/000000000...
# 3  //world-en.openfoodfacts.org/product/000000001...
# 4  //world-en.openfoodfacts.org/product/000000001...
#
# [5 rows x 165 columns]

# %% [markdown]
# # Step 5 of EDA Analysis

# %% [markdown]
# typecasting / conversion of datatype

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 165 entries, code to second_part
# dtypes: float64(107), object(58)
# memory usage: 448.2+ MB

# %%
# to convert it into integers

# %%
food['nutrition-score-fr_100g'].dropna()
# Out:
# 1         14.0
# 2          0.0
# 3         12.0
# 7          7.0
# 12        12.0
#           ...
# 355982    17.0
# 355985    -1.0
# 356005    -4.0
# 356010     0.0
# 356022     0.0
# Name: nutrition-score-fr_100g, Length: 254856, dtype: float64

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 165 entries, code to second_part
# dtypes: float64(107), object(58)
# memory usage: 448.2+ MB

# %%
food[['nutrition-score-fr_100g']] = food[['nutrition-score-fr_100g']].astype('str')
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 165 entries, code to second_part
# dtypes: float64(106), object(59)
# memory usage: 448.2+ MB

# %% [markdown]
# # Step 6 of EDA Analysis

# %%
# Summary statistics of data

# %%
food.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  283867.000000                283867.000000
# mean             NaN       1.876851                     0.023430
# std              NaN       2.501022                     0.153094
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      30.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            283867.000000
# mean                         NaN                                 0.059736
# std                          NaN                                 0.280660
# min                          NaN                                 0.000000
# 25%                          NaN                                 0.000000
# 50%                          NaN                                 0.000000
# 75%                          NaN                                 0.000000
# max                          NaN                                 6.000000
#
#        ingredients_that_may_be_from_palm_oil  nutrition_grade_uk  \
# count                                    0.0                 0.0
# mean                                     NaN                 NaN
# std                                      NaN                 NaN
# min                                      NaN                 NaN
# 25%                                      NaN                 NaN
# 50%                                      NaN                 NaN
# 75%                                      NaN                 NaN
# max                                      NaN                 NaN
#
#          energy_100g  energy-from-fat_100g      fat_100g  ...    ph_100g  \
# count  295367.000000            869.000000  2.794970e+05  ...  52.000000
# mean     1125.453320            587.216617  5.606587e+04  ...   6.476138
# std       936.825952            713.255708  2.963385e+07  ...   2.013490
# min         0.000000              0.000000  0.000000e+00  ...   0.000000
# 25%       382.000000             49.400000  1.000000e-01  ...   6.275000
# 50%      1092.000000            300.000000  5.290000e+00  ...   7.200000
# 75%      1674.000000            900.000000  2.000000e+01  ...   7.500000
# max    231199.000000           3830.000000  1.566667e+10  ...   8.400000
#
#        fruits-vegetables-nuts_100g  fruits-vegetables-nuts-estimate_100g  \
# count                  3228.000000                            404.000000
# mean                     33.392680                             60.360124
# std                      32.906834                             29.262350
# min                       0.000000                              0.000000
# 25%                       0.000000                             45.000000
# 50%                      25.000000                             58.000000
# 75%                      55.000000                             93.000000
# max                     100.000000                            100.000000
#
#        collagen-meat-protein-ratio_100g   cocoa_100g  chlorophyl_100g  \
# count                        182.000000  1383.000000              0.0
# mean                          15.362637    52.102675              NaN
# std                            3.692658    19.028361              NaN
# min                            8.000000     6.000000              NaN
# 25%                           12.000000    33.000000              NaN
# 50%                           15.000000    52.000000              NaN
# 75%                           15.000000    70.000000              NaN
# max                           25.000000   100.000000              NaN
#
#        carbon-footprint_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# count             278.000000            254856.000000                  0.0
# mean              335.790664                 8.980656                  NaN
# std               423.244817                 9.151757                  NaN
# min                 0.000000               -15.000000                  NaN
# 25%                82.650000                 1.000000                  NaN
# 50%               190.950000                 9.000000                  NaN
# 75%               378.700000                16.000000                  NaN
# max              2842.000000                40.000000                  NaN
#
#        water-hardness_100g
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN
#
# [8 rows x 106 columns]

# %% [markdown]
# # Step 6 of EDA Analysis

# %%
# Value count of a specific columns

# %%
food['creator'].value_counts()
# Out:
# usda-ndb-import               169868
# openfoodfacts-contributors     45805
# kiliweb                        36379
# date-limite-app                12679
# openfood-ch-import             11469
#                                ...
# leleio                             1
# bora                               1
# sevede28                           1
# brunoa                             1
# climboxing                         1
# Name: creator, Length: 3890, dtype: int64

# %%
# Finding unique value in a dataset
food['creator'].unique()
# Out:
# array(['openfoodfacts-contributors', 'usda-ndb-import', 'chris13', ...,
#        'robopetr', 'mmarquesma', 'jerem26260'], dtype=object)

# %% [markdown]
# # Step 8 of EDA Analysis

# %%
# deals with duplicate and/or Null values (meqn, median, mode or other methods)
food[food.creator =='usda-ndb-import']
# Out:
#                  code                                                url  \
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# 5               16100  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 355968  9780803738782  http://world-en.openfoodfacts.org/product/9780...
# 355985  9787461062105  http://world-en.openfoodfacts.org/product/9787...
# 356004  9836654056565  http://world-en.openfoodfacts.org/product/9836...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                 creator   created_t      created_datetime last_modified_t  \
# 1       usda-ndb-import  1489069957  2017-03-09T14:32:37Z      1489069957
# 2       usda-ndb-import  1489069957  2017-03-09T14:32:37Z      1489069957
# 3       usda-ndb-import  1489055731  2017-03-09T10:35:31Z      1489055731
# 4       usda-ndb-import  1489055653  2017-03-09T10:34:13Z      1489055653
# 5       usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# ...                 ...         ...                   ...             ...
# 355968  usda-ndb-import  1489069944  2017-03-09T14:32:24Z      1489069945
# 355985  usda-ndb-import  1489092300  2017-03-09T20:45:00Z      1489092300
# 356004  usda-ndb-import  1489055289  2017-03-09T10:28:09Z      1489055289
# 356022  usda-ndb-import  1489059076  2017-03-09T11:31:16Z      1491244499
# 356026  usda-ndb-import  1489072709  2017-03-09T15:18:29Z      1491244499
#
#        last_modified_datetime  \
# 1        2017-03-09T14:32:37Z
# 2        2017-03-09T14:32:37Z
# 3        2017-03-09T10:35:31Z
# 4        2017-03-09T10:34:13Z
# 5        2017-03-09T10:34:11Z
# ...                       ...
# 355968   2017-03-09T14:32:25Z
# 355985   2017-03-09T20:45:00Z
# 356004   2017-03-09T10:28:09Z
# 356022   2017-04-03T18:34:59Z
# 356026   2017-04-03T18:34:59Z
#
#                                              product_name generic_name  \
# 1                          Banana Chips Sweetened (Whole)          NaN
# 2                                                 Peanuts          NaN
# 3                                  Organic Salted Nut Mix          NaN
# 4                                         Organic Polenta          NaN
# 5                       Breadshop Honey Gone Nuts Granola          NaN
# ...                                                   ...          ...
# 355968                                      Organic Z Bar          NaN
# 355985                                    Natural Cassava          NaN
# 356004                                  Raspados Ice Bars          NaN
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...          NaN
# 356026                    Sugar Free Drink Mix, Peach Tea          NaN
#
#        quantity  ... collagen-meat-protein-ratio_100g cocoa_100g  \
# 1           NaN  ...                              NaN        NaN
# 2           NaN  ...                              NaN        NaN
# 3           NaN  ...                              NaN        NaN
# 4           NaN  ...                              NaN        NaN
# 5           NaN  ...                              NaN        NaN
# ...         ...  ...                              ...        ...
# 355968      NaN  ...                              NaN        NaN
# 355985      NaN  ...                              NaN        NaN
# 356004      NaN  ...                              NaN        NaN
# 356022      NaN  ...                              NaN        NaN
# 356026      NaN  ...                              NaN        NaN
#
#        chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 1                  NaN                   NaN                    14.0
# 2                  NaN                   NaN                     0.0
# 3                  NaN                   NaN                    12.0
# 4                  NaN                   NaN                     nan
# 5                  NaN                   NaN                     nan
# ...                ...                   ...                     ...
# 355968             NaN                   NaN                    11.0
# 355985             NaN                   NaN                    -1.0
# 356004             NaN                   NaN                     nan
# 356022             NaN                   NaN                     0.0
# 356026             NaN                   NaN                     nan
#
#        nutrition-score-uk_100g glycemic-index_100g water-hardness_100g  \
# 1                         14.0                 NaN                 NaN
# 2                          0.0                 NaN                 NaN
# 3                         12.0                 NaN                 NaN
# 4                          NaN                 NaN                 NaN
# 5                          NaN                 NaN                 NaN
# ...                        ...                 ...                 ...
# 355968                    11.0                 NaN                 NaN
# 355985                    -1.0                 NaN                 NaN
# 356004                     NaN                 NaN                 NaN
# 356022                     0.0                 NaN                 NaN
# 356026                     NaN                 NaN                 NaN
#
#        url type                                        second_part
# 1          http  //world-en.openfoodfacts.org/product/000000000...
# 2          http  //world-en.openfoodfacts.org/product/000000000...
# 3          http  //world-en.openfoodfacts.org/product/000000001...
# 4          http  //world-en.openfoodfacts.org/product/000000001...
# 5          http  //world-en.openfoodfacts.org/product/000000001...
# ...         ...                                                ...
# 355968     http  //world-en.openfoodfacts.org/product/978080373...
# 355985     http  //world-en.openfoodfacts.org/product/978746106...
# 356004     http  //world-en.openfoodfacts.org/product/983665405...
# 356022     http  //world-en.openfoodfacts.org/product/99567453/...
# 356026     http  //world-en.openfoodfacts.org/product/999990026...
#
# [169868 rows x 165 columns]

# %%
print("the datatypes in our dataset are ", food.dtypes)
# Out:
# the datatypes in our dataset are  code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# url type                    object
# second_part                 object
# Length: 165, dtype: object

# %% [markdown]
# # Step 9 of EDA Analysis

# %%
# check the normality and standard normal distribution

# %%
sns.histplot(food['creator'])

# %%
#sns.boxplot(food['creator'], color = 'red')

# %% [markdown]
# #Step 10 of EDA Analysis

# %%
# Correlations

corr = food.corr(method = 'pearson')
corr # this will display a correlation matrix
# Out:
#                                          no_nutriments  additives_n  \
# no_nutriments                                      NaN          NaN
# additives_n                                        NaN     1.000000
# ingredients_from_palm_oil_n                        NaN     0.131200
# ingredients_from_palm_oil                          NaN          NaN
# ingredients_that_may_be_from_palm_oil_n            NaN     0.297222
# ...                                                ...          ...
# chlorophyl_100g                                    NaN          NaN
# carbon-footprint_100g                              NaN     0.057470
# nutrition-score-uk_100g                            NaN     0.163740
# glycemic-index_100g                                NaN          NaN
# water-hardness_100g                                NaN          NaN
#
#                                          ingredients_from_palm_oil_n  \
# no_nutriments                                                    NaN
# additives_n                                                 0.131200
# ingredients_from_palm_oil_n                                 1.000000
# ingredients_from_palm_oil                                        NaN
# ingredients_that_may_be_from_palm_oil_n                     0.182316
# ...                                                              ...
# chlorophyl_100g                                                  NaN
# carbon-footprint_100g                                       0.053354
# nutrition-score-uk_100g                                     0.133987
# glycemic-index_100g                                              NaN
# water-hardness_100g                                              NaN
#
#                                          ingredients_from_palm_oil  \
# no_nutriments                                                  NaN
# additives_n                                                    NaN
# ingredients_from_palm_oil_n                                    NaN
# ingredients_from_palm_oil                                      NaN
# ingredients_that_may_be_from_palm_oil_n                        NaN
# ...                                                            ...
# chlorophyl_100g                                                NaN
# carbon-footprint_100g                                          NaN
# nutrition-score-uk_100g                                        NaN
# glycemic-index_100g                                            NaN
# water-hardness_100g                                            NaN
#
#                                          ingredients_that_may_be_from_palm_oil_n  \
# no_nutriments                                                                NaN
# additives_n                                                             0.297222
# ingredients_from_palm_oil_n                                             0.182316
# ingredients_from_palm_oil                                                    NaN
# ingredients_that_may_be_from_palm_oil_n                                 1.000000
# ...                                                                          ...
# chlorophyl_100g                                                              NaN
# carbon-footprint_100g                                                  -0.053449
# nutrition-score-uk_100g                                                 0.063743
# glycemic-index_100g                                                          NaN
# water-hardness_100g                                                          NaN
#
#                                          ingredients_that_may_be_from_palm_oil  \
# no_nutriments                                                              NaN
# additives_n                                                                NaN
# ingredients_from_palm_oil_n                                                NaN
# ingredients_from_palm_oil                                                  NaN
# ingredients_that_may_be_from_palm_oil_n                                    NaN
# ...                                                                        ...
# chlorophyl_100g                                                            NaN
# carbon-footprint_100g                                                      NaN
# nutrition-score-uk_100g                                                    NaN
# glycemic-index_100g                                                        NaN
# water-hardness_100g                                                        NaN
#
#                                          nutrition_grade_uk  energy_100g  \
# no_nutriments                                           NaN          NaN
# additives_n                                             NaN    -0.003085
# ingredients_from_palm_oil_n                             NaN     0.094609
# ingredients_from_palm_oil                               NaN          NaN
# ingredients_that_may_be_from_palm_oil_n                 NaN     0.024052
# ...                                                     ...          ...
# chlorophyl_100g                                         NaN          NaN
# carbon-footprint_100g                                   NaN     0.185085
# nutrition-score-uk_100g                                 NaN     0.566347
# glycemic-index_100g                                     NaN          NaN
# water-hardness_100g                                     NaN          NaN
#
#                                          energy-from-fat_100g  fat_100g  ...  \
# no_nutriments                                             NaN       NaN  ...
# additives_n                                         -0.102013 -0.110157  ...
# ingredients_from_palm_oil_n                          0.033191  0.063221  ...
# ingredients_from_palm_oil                                 NaN       NaN  ...
# ingredients_that_may_be_from_palm_oil_n              0.165693  0.018162  ...
# ...                                                       ...       ...  ...
# chlorophyl_100g                                           NaN       NaN  ...
# carbon-footprint_100g                                     NaN  0.084692  ...
# nutrition-score-uk_100g                              0.571355  0.596041  ...
# glycemic-index_100g                                       NaN       NaN  ...
# water-hardness_100g                                       NaN       NaN  ...
#
#                                           ph_100g  \
# no_nutriments                                 NaN
# additives_n                                   NaN
# ingredients_from_palm_oil_n                   NaN
# ingredients_from_palm_oil                     NaN
# ingredients_that_may_be_from_palm_oil_n       NaN
# ...                                           ...
# chlorophyl_100g                               NaN
# carbon-footprint_100g                         NaN
# nutrition-score-uk_100g                  0.337532
# glycemic-index_100g                           NaN
# water-hardness_100g                           NaN
#
#                                          fruits-vegetables-nuts_100g  \
# no_nutriments                                                    NaN
# additives_n                                                -0.191204
# ingredients_from_palm_oil_n                                -0.118696
# ingredients_from_palm_oil                                        NaN
# ingredients_that_may_be_from_palm_oil_n                    -0.113335
# ...                                                              ...
# chlorophyl_100g                                                  NaN
# carbon-footprint_100g                                      -0.704194
# nutrition-score-uk_100g                                    -0.388826
# glycemic-index_100g                                              NaN
# water-hardness_100g                                              NaN
#
#                                          fruits-vegetables-nuts-estimate_100g  \
# no_nutriments                                                             NaN
# additives_n                                                         -0.344685
# ingredients_from_palm_oil_n                                         -0.220970
# ingredients_from_palm_oil                                                 NaN
# ingredients_that_may_be_from_palm_oil_n                             -0.102304
# ...                                                                       ...
# chlorophyl_100g                                                           NaN
# carbon-footprint_100g                                                     NaN
# nutrition-score-uk_100g                                             -0.581079
# glycemic-index_100g                                                       NaN
# water-hardness_100g                                                       NaN
#
#                                          collagen-meat-protein-ratio_100g  \
# no_nutriments                                                         NaN
# additives_n                                                      0.049812
# ingredients_from_palm_oil_n                                           NaN
# ingredients_from_palm_oil                                             NaN
# ingredients_that_may_be_from_palm_oil_n                               NaN
# ...                                                                   ...
# chlorophyl_100g                                                       NaN
# carbon-footprint_100g                                                 NaN
# nutrition-score-uk_100g                                          0.576273
# glycemic-index_100g                                                   NaN
# water-hardness_100g                                                   NaN
#
#                                          cocoa_100g  chlorophyl_100g  \
# no_nutriments                                   NaN              NaN
# additives_n                               -0.215393              NaN
# ingredients_from_palm_oil_n               -0.226876              NaN
# ingredients_from_palm_oil                       NaN              NaN
# ingredients_that_may_be_from_palm_oil_n   -0.101091              NaN
# ...                                             ...              ...
# chlorophyl_100g                                 NaN              NaN
# carbon-footprint_100g                     -0.343673              NaN
# nutrition-score-uk_100g                   -0.518343              NaN
# glycemic-index_100g                             NaN              NaN
# water-hardness_100g                             NaN              NaN
#
#                                          carbon-footprint_100g  \
# no_nutriments                                              NaN
# additives_n                                           0.057470
# ingredients_from_palm_oil_n                           0.053354
# ingredients_from_palm_oil                                  NaN
# ingredients_that_may_be_from_palm_oil_n              -0.053449
# ...                                                        ...
# chlorophyl_100g                                            NaN
# carbon-footprint_100g                                 1.000000
# nutrition-score-uk_100g                               0.376876
# glycemic-index_100g                                        NaN
# water-hardness_100g                                        NaN
#
#                                          nutrition-score-uk_100g  \
# no_nutriments                                                NaN
# additives_n                                             0.163740
# ingredients_from_palm_oil_n                             0.133987
# ingredients_from_palm_oil                                    NaN
# ingredients_that_may_be_from_palm_oil_n                 0.063743
# ...                                                          ...
# chlorophyl_100g                                              NaN
# carbon-footprint_100g                                   0.376876
# nutrition-score-uk_100g                                 1.000000
# glycemic-index_100g                                          NaN
# water-hardness_100g                                          NaN
#
#                                          glycemic-index_100g  \
# no_nutriments                                            NaN
# additives_n                                              NaN
# ingredients_from_palm_oil_n                              NaN
# ingredients_from_palm_oil                                NaN
# ingredients_that_may_be_from_palm_oil_n                  NaN
# ...                                                      ...
# chlorophyl_100g                                          NaN
# carbon-footprint_100g                                    NaN
# nutrition-score-uk_100g                                  NaN
# glycemic-index_100g                                      NaN
# water-hardness_100g                                      NaN
#
#                                          water-hardness_100g
# no_nutriments                                            NaN
# additives_n                                              NaN
# ingredients_from_palm_oil_n                              NaN
# ingredients_from_palm_oil                                NaN
# ingredients_that_may_be_from_palm_oil_n                  NaN
# ...                                                      ...
# chlorophyl_100g                                          NaN
# carbon-footprint_100g                                    NaN
# nutrition-score-uk_100g                                  NaN
# glycemic-index_100g                                      NaN
# water-hardness_100g                                      NaN
#
# [106 rows x 106 columns]

# %%
sns.heatmap(corr, annot= True)
#this will show numbers with colors
